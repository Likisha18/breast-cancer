# %% [markdown]
# <a href="https://colab.research.google.com/github/Likisha18/breast-cancer/blob/main/electricvehiclepopulationeda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
data = pd.read_csv('/Electric_Vehicle_Population_Data.csv')
data
data.columns == 'nan'
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %%
# droprows = data.loc[data['Vehicle Location'] == 'nan'].index
# data = data.drop(droprows, axis = 0)
data

# data.loc[data['Vehicle Location'] != 'nan']
# data.loc[data['Vehicle Location'] == 'nan'].values
# Out:
#         VIN (1-10)     County         City State  Postal Code  Model Year  \
# 0       5YJ3E1EB4L     Yakima       Yakima    WA      98908.0        2020
# 1       5YJ3E1EA7K  San Diego    San Diego    CA      92101.0        2019
# 2       7JRBR0FL9M       Lane       Eugene    OR      97404.0        2021
# 3       5YJXCBE21K     Yakima       Yakima    WA      98908.0        2019
# 4       5UXKT0C5XH  Snohomish      Bothell    WA      98021.0        2017
# ...            ...        ...          ...   ...          ...         ...
# 124711  5YJ3E1EB6N  Snohomish       Monroe    WA      98272.0        2022
# 124712  KNDCM3LD2L     Pierce       Tacoma    WA      98406.0        2020
# 124713  7SAYGDEE0P    Whatcom   Bellingham    WA      98226.0        2023
# 124714  1G1FW6S03J     Pierce       Tacoma    WA      98444.0        2018
# 124715  1G1RC6E47F     Benton  Benton City    WA      99320.0        2015
#
#              Make    Model                   Electric Vehicle Type  \
# 0           TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 1           TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 2           VOLVO      S60  Plug-in Hybrid Electric Vehicle (PHEV)
# 3           TESLA  MODEL X          Battery Electric Vehicle (BEV)
# 4             BMW       X5  Plug-in Hybrid Electric Vehicle (PHEV)
# ...           ...      ...                                     ...
# 124711      TESLA  MODEL 3          Battery Electric Vehicle (BEV)
# 124712        KIA     NIRO  Plug-in Hybrid Electric Vehicle (PHEV)
# 124713      TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 124714  CHEVROLET  BOLT EV          Battery Electric Vehicle (BEV)
# 124715  CHEVROLET     VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                 Clean Alternative Fuel Vehicle Eligible             322
# 1                 Clean Alternative Fuel Vehicle Eligible             220
# 2                   Not eligible due to low battery range              22
# 3                 Clean Alternative Fuel Vehicle Eligible             289
# 4                   Not eligible due to low battery range              14
# ...                                                   ...             ...
# 124711  Eligibility unknown as battery range has not b...               0
# 124712              Not eligible due to low battery range              26
# 124713  Eligibility unknown as battery range has not b...               0
# 124714            Clean Alternative Fuel Vehicle Eligible             238
# 124715            Clean Alternative Fuel Vehicle Eligible              38
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 0               0                  14.0       127175366
# 1               0                   NaN       266614659
# 2               0                   NaN       144502018
# 3               0                  14.0       477039944
# 4               0                   1.0       106314946
# ...           ...                   ...             ...
# 124711          0                  39.0       192999061
# 124712          0                  27.0       113346250
# 124713          0                  42.0       232751305
# 124714          0                  29.0       102589007
# 124715          0                  16.0       476974718
#
#                    Vehicle Location  \
# 0       POINT (-120.56916 46.58514)
# 1       POINT (-117.16171 32.71568)
# 2       POINT (-123.12802 44.09573)
# 3       POINT (-120.56916 46.58514)
# 4        POINT (-122.18384 47.8031)
# ...                             ...
# 124711   POINT (-121.98087 47.8526)
# 124712  POINT (-122.52054 47.26887)
# 124713   POINT (-122.49756 48.7999)
# 124714  POINT (-122.46495 47.16778)
# 124715  POINT (-119.48756 46.26543)
#
#                                          Electric Utility  2020 Census Tract
# 0                                              PACIFICORP       5.307700e+10
# 1                                                     NaN       6.073005e+09
# 2                                                     NaN       4.103900e+10
# 3                                              PACIFICORP       5.307700e+10
# 4                                  PUGET SOUND ENERGY INC       5.306105e+10
# ...                                                   ...                ...
# 124711                             PUGET SOUND ENERGY INC       5.306105e+10
# 124712  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305306e+10
# 124713  PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM CO...       5.307300e+10
# 124714  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305307e+10
# 124715  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF B...       5.300501e+10
#
# [124716 rows x 17 columns]

# %%
if (data == 'nan').values.any():
    print('The dataset contains only the value "strin"')
else:
    print('The dataset contains other values besides "strin"')
# Out:
# The dataset contains other values besides "strin"

# %%
# data.County.unique()

# %%
data.Make.unique()
# Out:
# array(['TESLA', 'VOLVO', 'BMW', 'NISSAN', 'MERCEDES-BENZ', 'KIA',
#        'CHEVROLET', 'FORD', 'MINI', 'TOYOTA', 'FIAT', 'RIVIAN', 'SUBARU',
#        'AUDI', 'PORSCHE', 'JEEP', 'HYUNDAI', 'CHRYSLER', 'VOLKSWAGEN',
#        'HONDA', 'SMART', 'LINCOLN', 'MITSUBISHI', 'CADILLAC', 'POLESTAR',
#        'JAGUAR', 'LUCID MOTORS', 'LEXUS', 'LAND ROVER', 'GENESIS',
#        'FISKER', 'AZURE DYNAMICS', 'WHEEGO ELECTRIC CARS', 'TH!NK',
#        'BENTLEY'], dtype=object)

# %%
# data.groupby('Make')['Model'].count().sort_values(ascending = False)

# %%
plt.figure(figsize = (15, 5))
ax = sns.countplot(data = data, x = 'Make',  order = data.groupby('Make')['Model'].count().sort_values(ascending = False).index, orient = 'v')
plt.xticks(rotation = 45, ha = 'right')
labels = data.groupby('Make')['Model'].count().sort_values(ascending = False).values
# plt.bar_label(ax.containers[0], labels = labels)
plt.tight_layout()
plt.show()

# %%
data['Electric Vehicle Type'].unique()
# Out:
# array(['Battery Electric Vehicle (BEV)',
#        'Plug-in Hybrid Electric Vehicle (PHEV)'], dtype=object)

# %%
data['Electric Vehicle Type'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 0)
plt.show()

# %%
data['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].unique()
# Out:
# array(['Clean Alternative Fuel Vehicle Eligible',
#        'Not eligible due to low battery range',
#        'Eligibility unknown as battery range has not been researched'],
#       dtype=object)

# %%
plt.figure(figsize = (12, 5))
ax = sns.countplot(data = data, x = 'Clean Alternative Fuel Vehicle (CAFV) Eligibility')
plt.xticks(rotation = 15, ha = 'center')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (12, 5))
ax = sns.countplot(data = data, x = 'Model Year')
plt.xticks(rotation = 15, ha = 'center')
plt.tight_layout()
plt.show()

# %%
sns.histplot(data = data, x = 'Electric Range', bins = 5, kde = True)
# Out:
# <Axes: xlabel='Electric Range', ylabel='Count'>

# %%
plt.figure(figsize = (15, 5))
data.Model.value_counts().head(15).plot(kind = 'bar')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize = (15, 5))
data.Model.value_counts().tail(15).plot(kind = 'bar')
plt.xticks(rotation = 45)
plt.show()

# %%
data['Base MSRP'].unique()
# Out:
# array([     0,  31950,  69900,  52900,  33950,  64950,  54950,  75095,
#         32250,  81100,  53400,  39995,  44100,  36800,  36900,  98950,
#         45600,  55700,  34995,  59900,  43700, 110950, 102000,  52650,
#        184400,  90700,  89100,  91250, 109000,  32995, 845000])

# %%
data.loc[data.Model == 'MODEL X']
# Out:
#         VIN (1-10)     County           City State  Postal Code  Model Year  \
# 3       5YJXCBE21K     Yakima         Yakima    WA      98908.0        2019
# 20      5YJXCBE2XH   Thurston        Olympia    WA      98513.0        2017
# 69      5YJXCDE21K  Snohomish     Marysville    WA      98271.0        2019
# 105     5YJXCBE45G  Snohomish        Bothell    WA      98021.0        2016
# 113     5YJXCBE24K       King        Seattle    WA      98112.0        2019
# ...            ...        ...            ...   ...          ...         ...
# 124596  5YJXCAE21M     Island  Camano Island    WA      98282.0        2021
# 124610  7SAXCBE52N       King   Maple Valley    WA      98038.0        2022
# 124611  5YJXCAE29L  Snohomish       Stanwood    WA      98292.0        2020
# 124646  5YJXCBE29H       King        Seattle    WA      98109.0        2017
# 124698  7SAXCBE62N  Snohomish       Lynnwood    WA      98087.0        2022
#
#          Make    Model           Electric Vehicle Type  \
# 3       TESLA  MODEL X  Battery Electric Vehicle (BEV)
# 20      TESLA  MODEL X  Battery Electric Vehicle (BEV)
# 69      TESLA  MODEL X  Battery Electric Vehicle (BEV)
# 105     TESLA  MODEL X  Battery Electric Vehicle (BEV)
# 113     TESLA  MODEL X  Battery Electric Vehicle (BEV)
# ...       ...      ...                             ...
# 124596  TESLA  MODEL X  Battery Electric Vehicle (BEV)
# 124610  TESLA  MODEL X  Battery Electric Vehicle (BEV)
# 124611  TESLA  MODEL X  Battery Electric Vehicle (BEV)
# 124646  TESLA  MODEL X  Battery Electric Vehicle (BEV)
# 124698  TESLA  MODEL X  Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 3                 Clean Alternative Fuel Vehicle Eligible             289
# 20                Clean Alternative Fuel Vehicle Eligible             200
# 69                Clean Alternative Fuel Vehicle Eligible             289
# 105               Clean Alternative Fuel Vehicle Eligible             200
# 113               Clean Alternative Fuel Vehicle Eligible             289
# ...                                                   ...             ...
# 124596  Eligibility unknown as battery range has not b...               0
# 124610  Eligibility unknown as battery range has not b...               0
# 124611            Clean Alternative Fuel Vehicle Eligible             293
# 124646            Clean Alternative Fuel Vehicle Eligible             200
# 124698  Eligibility unknown as battery range has not b...               0
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 3               0                  14.0       477039944
# 20              0                   2.0       131584841
# 69              0                  38.0       254402249
# 105             0                   1.0       232691273
# 113             0                  43.0       141213817
# ...           ...                   ...             ...
# 124596          0                  10.0       131497747
# 124610          0                   5.0       214982498
# 124611          0                  10.0         9324381
# 124646          0                  36.0       127359683
# 124698          0                  21.0       192485254
#
#                    Vehicle Location  \
# 3       POINT (-120.56916 46.58514)
# 20      POINT (-122.80277 46.99409)
# 69      POINT (-122.19388 48.15353)
# 105      POINT (-122.18384 47.8031)
# 113     POINT (-122.30716 47.62687)
# ...                             ...
# 124596  POINT (-122.40049 48.23986)
# 124610  POINT (-122.04526 47.39394)
# 124611  POINT (-122.37265 48.24159)
# 124646  POINT (-122.35022 47.63824)
# 124698  POINT (-122.27981 47.85727)
#
#                                          Electric Utility  2020 Census Tract
# 3                                              PACIFICORP       5.307700e+10
# 20                                 PUGET SOUND ENERGY INC       5.306701e+10
# 69                                                    NaN       5.306194e+10
# 105                                PUGET SOUND ENERGY INC       5.306105e+10
# 113          CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# ...                                                   ...                ...
# 124596  BONNEVILLE POWER ADMINISTRATION||PUD 1 OF SNOH...       5.302997e+10
# 124610      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 124611  BONNEVILLE POWER ADMINISTRATION||PUD 1 OF SNOH...       5.306105e+10
# 124646       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 124698                             PUGET SOUND ENERGY INC       5.306105e+10
#
# [4647 rows x 17 columns]

# %%
droprows = data.loc[data['Vehicle Location'] == 'nan'].index
data = data.drop(droprows, axis = 0)
data
data.loc[data['Vehicle Location'] == 'nan'].index
# Out:
# Int64Index([], dtype='int64')

# %%
type(data['Vehicle Location'])
# Out:
# pandas.core.series.Series

# %%
# from shapely import wkt
# import geopandas

# # data['Vehicle Location'] = data['Vehicle Location'].astype(str)
# data['Vehicle Location'] = geopandas.GeoSeries.from_wkt(data['Vehicle Location'])
# data = geopandas.GeoDataFrame(data, geometry='Vehicle Location')

# # gdf.head()
# # data.loc[data['Vehicle Location'] == 'nan']

# %%
# # plt.figure(figsize =(15, 5))
# world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# ax = world[world.continent == 'North America'].plot(color='white', edgecolor='black')

# data.plot(ax=ax, color='red', figsize=(15, 5))

# plt.show()

# %%
## Work in progress
## upvote if you like
## comment if any
## suggestions are most welcome

# %%
## For some reason geopandas library is giving error, help if you can
